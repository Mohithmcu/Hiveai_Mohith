# %% [markdown]
# # 03. Golden Set Sampling & Stratification
#
# This notebook demonstrates the stratified sampling protocol used to construct `eval/golden_set.csv` across intents, message lengths, and deliberate adversarial edge cases.

# %%
import pandas as pd
from pathlib import Path

golden_df = pd.read_csv("../eval/golden_set.csv")
print(f"Total Golden Set Size: {len(golden_df)}")
golden_df.head()

# %%
print("Distribution by Intent:")
print(golden_df['intent_gold'].value_counts())
print("\nDistribution by Escalation:")
print(golden_df['escalate_gold'].value_counts())
print("\nDistribution by Difficulty:")
print(golden_df['difficulty'].value_counts())
